# %%
# EDA

# %%
# Food Classification 2022 https://www.kaggle.com/datasets/sainikhileshreddy/food-recognition-2022

# %%
# import packages
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2  # For OpenCV
from PIL import Image  # For Pillow
import os
# Out:
# /tmp/ipykernel_614/3735891831.py:3: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
# image EDA
# Load an image
img = cv2.imread('/workspace/gotmeals/EDA/FoodSeg103/Images/ann_dir/test/00000048.png')
# Convert BGR to RGB (OpenCV uses BGR by default)
img_rgb = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img_rgb)
plt.show()

# %%
# analyze text data- git_LFS need to get original file and reinput into this folder- restored into data/sample_data/Data_melia
# contains the categories of the food classes
categories = pd.read_csv('/workspace/gotmeals/data/sample_data/Data_melia/category_id.txt', delimiter='some_delimiter', header=None)
print(categories.head())
# Out:
#                  0
# 0    0\tbackground
# 1         1\tcandy
# 2      2\tegg tart
# 3  3\tfrench fries
# 4     4\tchocolate
# /tmp/ipykernel_614/3699163232.py:3: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   categories = pd.read_csv('/workspace/gotmeals/data/sample_data/Data_melia/category_id.txt', delimiter='some_delimiter', header=None)

# %%
img_path = '/workspace/gotmeals/EDA/FoodSeg103/Images/img_dir/test/00000048.jpg'
img_pil = Image.open(img_path)
plt.imshow(img_pil)
plt.show()

# %%
# text data of .txt files
train_files = pd.read_csv('/workspace/gotmeals/EDA/FoodSeg103/ImageSets/train.txt', delimiter='some_delimiter', header=None)
print(train_files.head())
# Out:
#               0
# 0  00000000.jpg
# 1  00000001.jpg
# 2  00000002.jpg
# 3  00000003.jpg
# 4  00000004.jpg
# /tmp/ipykernel_614/127715156.py:2: ParserWarning: Falling back to the 'python' engine because the 'c' engine does not support regex separators (separators > 1 char and different from '\s+' are interpreted as regex); you can avoid this warning by specifying engine='python'.
#   train_files = pd.read_csv('/workspace/gotmeals/EDA/FoodSeg103/ImageSets/train.txt', delimiter='some_delimiter', header=None)

# %% [markdown]
# Shows that these train and test .txt files (ImageSets folder) are the labels of the images from the "Images" folder
